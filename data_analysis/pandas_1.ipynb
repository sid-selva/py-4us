# %%
import pandas as pd

# %%
import numpy as np
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#     Rank                   Team     GP  Won  Lost  Tied   Pct.  \
# 0      1      Green Bay Packers  1,401  782   581    38  0.572
# 1      2         Dallas Cowboys    947  538   403     6  0.571
# 2      3   New England Patriots    949  529   411     9  0.562
# 3      4          Chicago Bears  1,435  783   610    42  0.560
# 4      5       Baltimore Ravens    417  233   183     1  0.560
# 5      6         Miami Dolphins    865  476   385     4  0.553
# 6      7      Minnesota Vikings    935  503   421    11  0.544
# 7      8     Kansas City Chiefs    949  507   430    12  0.541
# 8      9    Pittsburgh Steelers  1,237  652   563    22  0.536
# 9     10    San Francisco 49ers  1,067  561   492    14  0.532
# 10    11  Indianapolis Colts[d]  1,031  543   481     7  0.530
# 11    12        New York Giants  1,370  706   631    33  0.527
# 12    13         Denver Broncos    949  495   444    10  0.527
# 13    14      Las Vegas Raiders    949  491   447    11  0.523
# 14    15       Seattle Seahawks    725  374   350     1  0.517
# 15    16       Los Angeles Rams  1,200  599   580    21  0.508
# 16    17   Los Angeles Chargers    949  468   470    11  0.499
# 17    18  Washington Commanders  1,267  617   622    28  0.498
# 18    19       Tennessee Titans    949  463   480     6  0.491
# 19    20    Cleveland Browns[e]  1,019  494   514    11  0.490
# 20    21    Philadelphia Eagles  1,253  599   627    27  0.489
# 21    22          Buffalo Bills    949  449   492     8  0.477
# 22    23      Carolina Panthers    433  205   227     1  0.475
# 23    24     New Orleans Saints    851  396   450     5  0.468
# 24    25          Detroit Lions  1,298  570   694    34  0.452
# 25    26     Cincinnati Bengals    837  373   459     5  0.449
# 26    27          New York Jets    949  414   527     8  0.440
# 27    28        Atlanta Falcons    865  376   483     6  0.438
# 28    29         Houston Texans    321  139   182     0  0.433
# 29    30      Arizona Cardinals  1,395  577   777    41  0.428
# 30    31   Jacksonville Jaguars    433  180   253     0  0.416
# 31    32   Tampa Bay Buccaneers    725  291   433     1  0.402
#
#     First NFL season   Division
# 0               1921  NFC North
# 1               1960   NFC East
# 2               1960   AFC East
# 3               1920  NFC North
# 4               1996  AFC North
# 5               1966   AFC East
# 6               1961  NFC North
# 7               1960   AFC West
# 8               1933  AFC North
# 9               1950   NFC West
# 10              1953  AFC South
# 11              1925   NFC East
# 12              1960   AFC West
# 13              1960   AFC West
# 14              1976   NFC West
# 15              1937   NFC West
# 16              1960   AFC West
# 17              1932   NFC East
# 18              1960  AFC South
# 19              1950  AFC North
# 20              1933   NFC East
# 21              1960   AFC East
# 22              1995  NFC South
# 23              1967  NFC South
# 24              1930  NFC North
# 25              1968  AFC North
# 26              1960   AFC East
# 27              1966  NFC South
# 28              2002  AFC South
# 29              1920   NFC West
# 30              1995  AFC South
# 31              1976  NFC South

# %%
help(pd.read_clipboard)
# Out:
# Help on function read_clipboard in module pandas.io.clipboards:
#
# read_clipboard(sep: 'str' = '\\s+', **kwargs)
#     Read text from clipboard and pass to read_csv.
#
#     Parameters
#     ----------
#     sep : str, default '\s+'
#         A string or regex delimiter. The default of '\s+' denotes
#         one or more whitespace characters.
#
#     **kwargs
#         See read_csv for the full argument list.
#
#     Returns
#     -------
#     DataFrame
#         A parsed DataFrame object.

# %%
nfl_frame.to_csv('nfl_wl.csv', index=False)

# %%
nfl_frame['First NFL season']
# Out:
# 0     1921
# 1     1960
# 2     1960
# 3     1920
# 4     1996
# 5     1966
# 6     1961
# 7     1960
# 8     1933
# 9     1950
# 10    1953
# 11    1925
# 12    1960
# 13    1960
# 14    1976
# 15    1937
# 16    1960
# 17    1932
# 18    1960
# 19    1950
# 20    1933
# 21    1960
# 22    1995
# 23    1967
# 24    1930
# 25    1968
# 26    1960
# 27    1966
# 28    2002
# 29    1920
# 30    1995
# 31    1976
# Name: First NFL season, dtype: int64

# %%
DataFrame(nfl_frame,columns=['Team','First NFL season','GP'])
# Out:
#                      Team  First NFL season     GP
# 0       Green Bay Packers              1921  1,401
# 1          Dallas Cowboys              1960    947
# 2    New England Patriots              1960    949
# 3           Chicago Bears              1920  1,435
# 4        Baltimore Ravens              1996    417
# 5          Miami Dolphins              1966    865
# 6       Minnesota Vikings              1961    935
# 7      Kansas City Chiefs              1960    949
# 8     Pittsburgh Steelers              1933  1,237
# 9     San Francisco 49ers              1950  1,067
# 10  Indianapolis Colts[d]              1953  1,031
# 11        New York Giants              1925  1,370
# 12         Denver Broncos              1960    949
# 13      Las Vegas Raiders              1960    949
# 14       Seattle Seahawks              1976    725
# 15       Los Angeles Rams              1937  1,200
# 16   Los Angeles Chargers              1960    949
# 17  Washington Commanders              1932  1,267
# 18       Tennessee Titans              1960    949
# 19    Cleveland Browns[e]              1950  1,019
# 20    Philadelphia Eagles              1933  1,253
# 21          Buffalo Bills              1960    949
# 22      Carolina Panthers              1995    433
# 23     New Orleans Saints              1967    851
# 24          Detroit Lions              1930  1,298
# 25     Cincinnati Bengals              1968    837
# 26          New York Jets              1960    949
# 27        Atlanta Falcons              1966    865
# 28         Houston Texans              2002    321
# 29      Arizona Cardinals              1920  1,395
# 30   Jacksonville Jaguars              1995    433
# 31   Tampa Bay Buccaneers              1976    725

# %%
nfl_frame[['Team','GP']]
# Out:
#                      Team     GP
# 0       Green Bay Packers  1,401
# 1          Dallas Cowboys    947
# 2    New England Patriots    949
# 3           Chicago Bears  1,435
# 4        Baltimore Ravens    417
# 5          Miami Dolphins    865
# 6       Minnesota Vikings    935
# 7      Kansas City Chiefs    949
# 8     Pittsburgh Steelers  1,237
# 9     San Francisco 49ers  1,067
# 10  Indianapolis Colts[d]  1,031
# 11        New York Giants  1,370
# 12         Denver Broncos    949
# 13      Las Vegas Raiders    949
# 14       Seattle Seahawks    725
# 15       Los Angeles Rams  1,200
# 16   Los Angeles Chargers    949
# 17  Washington Commanders  1,267
# 18       Tennessee Titans    949
# 19    Cleveland Browns[e]  1,019
# 20    Philadelphia Eagles  1,253
# 21          Buffalo Bills    949
# 22      Carolina Panthers    433
# 23     New Orleans Saints    851
# 24          Detroit Lions  1,298
# 25     Cincinnati Bengals    837
# 26          New York Jets    949
# 27        Atlanta Falcons    865
# 28         Houston Texans    321
# 29      Arizona Cardinals  1,395
# 30   Jacksonville Jaguars    433
# 31   Tampa Bay Buccaneers    725

# %%
nfl_frame.iloc[3]
#index
# Out:
# Rank                            4
# Team                Chicago Bears
# GP                          1,435
# Won                           783
# Lost                          610
# Tied                           42
# Pct.                         0.56
# First NFL season             1920
# Division                NFC North
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#     Rank                   Team     GP  Won  Lost  Tied   Pct.  \
# 0      1      Green Bay Packers  1,401  782   581    38  0.572
# 1      2         Dallas Cowboys    947  538   403     6  0.571
# 2      3   New England Patriots    949  529   411     9  0.562
# 3      4          Chicago Bears  1,435  783   610    42  0.560
# 4      5       Baltimore Ravens    417  233   183     1  0.560
# 5      6         Miami Dolphins    865  476   385     4  0.553
# 6      7      Minnesota Vikings    935  503   421    11  0.544
# 7      8     Kansas City Chiefs    949  507   430    12  0.541
# 8      9    Pittsburgh Steelers  1,237  652   563    22  0.536
# 9     10    San Francisco 49ers  1,067  561   492    14  0.532
# 10    11  Indianapolis Colts[d]  1,031  543   481     7  0.530
# 11    12        New York Giants  1,370  706   631    33  0.527
# 12    13         Denver Broncos    949  495   444    10  0.527
# 13    14      Las Vegas Raiders    949  491   447    11  0.523
# 14    15       Seattle Seahawks    725  374   350     1  0.517
# 15    16       Los Angeles Rams  1,200  599   580    21  0.508
# 16    17   Los Angeles Chargers    949  468   470    11  0.499
# 17    18  Washington Commanders  1,267  617   622    28  0.498
# 18    19       Tennessee Titans    949  463   480     6  0.491
# 19    20    Cleveland Browns[e]  1,019  494   514    11  0.490
# 20    21    Philadelphia Eagles  1,253  599   627    27  0.489
# 21    22          Buffalo Bills    949  449   492     8  0.477
# 22    23      Carolina Panthers    433  205   227     1  0.475
# 23    24     New Orleans Saints    851  396   450     5  0.468
# 24    25          Detroit Lions  1,298  570   694    34  0.452
# 25    26     Cincinnati Bengals    837  373   459     5  0.449
# 26    27          New York Jets    949  414   527     8  0.440
# 27    28        Atlanta Falcons    865  376   483     6  0.438
# 28    29         Houston Texans    321  139   182     0  0.433
# 29    30      Arizona Cardinals  1,395  577   777    41  0.428
# 30    31   Jacksonville Jaguars    433  180   253     0  0.416
# 31    32   Tampa Bay Buccaneers    725  291   433     1  0.402
#
#     First NFL season   Division         Stadium
# 0               1921  NFC North  Levi's Stadium
# 1               1960   NFC East  Levi's Stadium
# 2               1960   AFC East  Levi's Stadium
# 3               1920  NFC North  Levi's Stadium
# 4               1996  AFC North  Levi's Stadium
# 5               1966   AFC East  Levi's Stadium
# 6               1961  NFC North  Levi's Stadium
# 7               1960   AFC West  Levi's Stadium
# 8               1933  AFC North  Levi's Stadium
# 9               1950   NFC West  Levi's Stadium
# 10              1953  AFC South  Levi's Stadium
# 11              1925   NFC East  Levi's Stadium
# 12              1960   AFC West  Levi's Stadium
# 13              1960   AFC West  Levi's Stadium
# 14              1976   NFC West  Levi's Stadium
# 15              1937   NFC West  Levi's Stadium
# 16              1960   AFC West  Levi's Stadium
# 17              1932   NFC East  Levi's Stadium
# 18              1960  AFC South  Levi's Stadium
# 19              1950  AFC North  Levi's Stadium
# 20              1933   NFC East  Levi's Stadium
# 21              1960   AFC East  Levi's Stadium
# 22              1995  NFC South  Levi's Stadium
# 23              1967  NFC South  Levi's Stadium
# 24              1930  NFC North  Levi's Stadium
# 25              1968  AFC North  Levi's Stadium
# 26              1960   AFC East  Levi's Stadium
# 27              1966  NFC South  Levi's Stadium
# 28              2002  AFC South  Levi's Stadium
# 29              1920   NFC West  Levi's Stadium
# 30              1995  AFC South  Levi's Stadium
# 31              1976  NFC South  Levi's Stadium

# %%
stadiums =Series(['Levis Stadium'])

# %%
stadiums
# Out:
# 0    Levis StadiumLevis StadiumLevis StadiumLevis S...
# dtype: object

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#     Rank                   Team     GP  Won  Lost  Tied   Pct.  \
# 0      1      Green Bay Packers  1,401  782   581    38  0.572
# 1      2         Dallas Cowboys    947  538   403     6  0.571
# 2      3   New England Patriots    949  529   411     9  0.562
# 3      4          Chicago Bears  1,435  783   610    42  0.560
# 4      5       Baltimore Ravens    417  233   183     1  0.560
# 5      6         Miami Dolphins    865  476   385     4  0.553
# 6      7      Minnesota Vikings    935  503   421    11  0.544
# 7      8     Kansas City Chiefs    949  507   430    12  0.541
# 8      9    Pittsburgh Steelers  1,237  652   563    22  0.536
# 9     10    San Francisco 49ers  1,067  561   492    14  0.532
# 10    11  Indianapolis Colts[d]  1,031  543   481     7  0.530
# 11    12        New York Giants  1,370  706   631    33  0.527
# 12    13         Denver Broncos    949  495   444    10  0.527
# 13    14      Las Vegas Raiders    949  491   447    11  0.523
# 14    15       Seattle Seahawks    725  374   350     1  0.517
# 15    16       Los Angeles Rams  1,200  599   580    21  0.508
# 16    17   Los Angeles Chargers    949  468   470    11  0.499
# 17    18  Washington Commanders  1,267  617   622    28  0.498
# 18    19       Tennessee Titans    949  463   480     6  0.491
# 19    20    Cleveland Browns[e]  1,019  494   514    11  0.490
# 20    21    Philadelphia Eagles  1,253  599   627    27  0.489
# 21    22          Buffalo Bills    949  449   492     8  0.477
# 22    23      Carolina Panthers    433  205   227     1  0.475
# 23    24     New Orleans Saints    851  396   450     5  0.468
# 24    25          Detroit Lions  1,298  570   694    34  0.452
# 25    26     Cincinnati Bengals    837  373   459     5  0.449
# 26    27          New York Jets    949  414   527     8  0.440
# 27    28        Atlanta Falcons    865  376   483     6  0.438
# 28    29         Houston Texans    321  139   182     0  0.433
# 29    30      Arizona Cardinals  1,395  577   777    41  0.428
# 30    31   Jacksonville Jaguars    433  180   253     0  0.416
# 31    32   Tampa Bay Buccaneers    725  291   433     1  0.402
#
#     First NFL season   Division
# 0               1921  NFC North
# 1               1960   NFC East
# 2               1960   AFC East
# 3               1920  NFC North
# 4               1996  AFC North
# 5               1966   AFC East
# 6               1961  NFC North
# 7               1960   AFC West
# 8               1933  AFC North
# 9               1950   NFC West
# 10              1953  AFC South
# 11              1925   NFC East
# 12              1960   AFC West
# 13              1960   AFC West
# 14              1976   NFC West
# 15              1937   NFC West
# 16              1960   AFC West
# 17              1932   NFC East
# 18              1960  AFC South
# 19              1950  AFC North
# 20              1933   NFC East
# 21              1960   AFC East
# 22              1995  NFC South
# 23              1967  NFC South
# 24              1930  NFC North
# 25              1968  AFC North
# 26              1960   AFC East
# 27              1966  NFC South
# 28              2002  AFC South
# 29              1920   NFC West
# 30              1995  AFC South
# 31              1976  NFC South

# %% [markdown]
# ### Index Objects

# %%
my_ser = Series([1,2,3,4], index=['A','B','C','D'])

# %%
my_index = my_ser.index

# %%
my_index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
my_index[2]
# Out:
# 'C'

# %%
my_index[2:]
# Out:
# Index(['C', 'D'], dtype='object')

# %%
# Reindex

# %%
from numpy.random import randn

# %%
ser1 = Series([1,2,3,4],index=['A','B','C','D'])

ser1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
ser2 = ser1.reindex(['A','B','C','D','E','F'])

ser2
# Out:
# A    1.0
# B    2.0
# C    3.0
# D    4.0
# E    NaN
# F    NaN
# dtype: float64

# %%
ser2 = ser1.reindex(['A','B','C','D','E','F'], fill_value=0)
ser2
# Out:
# A    1
# B    2
# C    3
# D    4
# E    0
# F    0
# dtype: int64

# %%
#Reindexing rows, columns or both

#Lets make a datafram ewith some random values
dframe = DataFrame(randn(25).reshape((5,5)),index=['A','B','D','E','F'],columns=['col1','col2','col3','col4','col5'])

#Show
dframe
# Out:
#        col1      col2      col3      col4      col5
# A -0.224829  0.555415 -0.848704 -0.842524  1.118003
# B -0.259649 -1.271376  0.703033 -1.306404  0.427237
# D  1.856832 -0.523625  0.517871 -0.639632 -0.518694
# E  0.079110 -0.240307  1.240224 -0.535114 -0.506809
# F -1.853027  0.756134  0.419102 -0.434746 -0.794819

# %%
#Notice we forgot 'C' , lets reindex it into dframe
dframe2 = dframe.reindex(['A','B','C','D','E','F'])

# %%
#Can also explicitly reindex columns
new_columns = ['col1','col2','col3','col4','col5','col6']

dframe2.reindex(columns=new_columns)
# Out:
#        col1      col2      col3      col4      col5  col6
# A -0.224829  0.555415 -0.848704 -0.842524  1.118003   NaN
# B -0.259649 -1.271376  0.703033 -1.306404  0.427237   NaN
# C       NaN       NaN       NaN       NaN       NaN   NaN
# D  1.856832 -0.523625  0.517871 -0.639632 -0.518694   NaN
# E  0.079110 -0.240307  1.240224 -0.535114 -0.506809   NaN
# F -1.853027  0.756134  0.419102 -0.434746 -0.794819   NaN

# %%
dframe.loc[['A','B','D','E','F']]
# Out:
#        col1      col2      col3      col4      col5
# A -0.224829  0.555415 -0.848704 -0.842524  1.118003
# B -0.259649 -1.271376  0.703033 -1.306404  0.427237
# D  1.856832 -0.523625  0.517871 -0.639632 -0.518694
# E  0.079110 -0.240307  1.240224 -0.535114 -0.506809
# F -1.853027  0.756134  0.419102 -0.434746 -0.794819

# %%
#Create a new series to play with
ser1 = Series(np.arange(3),index=['a','b','c'])

#Show
ser1
# Out:
# a    0
# b    1
# c    2
# dtype: int32

# %%
#Now let's drop an index
ser1.drop('b')
# Out:
# a    0
# c    2
# dtype: int32

# %%
#With a DataFrame we can drop values from either axis
dframe1 = DataFrame(np.arange(9).reshape((3,3)),index=['SF','LA','NY'],columns=['pop','size','year'])

#Show (remember just random values)
dframe1
# Out:
#     pop  size  year
# SF    0     1     2
# LA    3     4     5
# NY    6     7     8

# %%
#Now dropping a row
dframe1.drop('LA')
# Out:
#     pop  size  year
# SF    0     1     2
# NY    6     7     8

# %%
#Or we could drop a column

#Need to specify that axis is 1, not 0
dframe1.drop('year',axis=1)
# Out:
#     pop  size
# SF    0     1
# LA    3     4
# NY    6     7

# %%
#Lets try some Series indexing
ser1 = Series(np.arange(3),index=['A','B','C'])

#multiply all values by 2, to avoid confusion in future
ser1 = 2*ser1

#Show
ser1
# Out:
# A    0
# B    2
# C    4
# dtype: int32

# %%
#Can grab entry by index name
ser1['B']
# Out:
# 2

# %%
#Or grab by index 
ser1[1]
# Out:
# 2

# %%
#Can also grab by index range
ser1[0:3]
# Out:
# A    0
# B    2
# C    4
# dtype: int32

# %%
#Or grab range by range of index values
ser1[['A','B','C']]
# Out:
# A    0
# B    2
# C    4
# dtype: int32

# %%
#Or grab by logic
ser1[ser1>3]
# Out:
# C    4
# dtype: int32

# %%
#Now let's see sleection in a DataFrame

dframe = DataFrame(np.arange(25).reshape((5,5)),index=['NYC','LA','SF','DC','Chi'],columns=['A','B','C','D','E'])

#Show
dframe
# Out:
#       A   B   C   D   E
# NYC   0   1   2   3   4
# LA    5   6   7   8   9
# SF   10  11  12  13  14
# DC   15  16  17  18  19
# Chi  20  21  22  23  24

# %%
#Select by column name
dframe['B']
# Out:
# NYC     1
# LA      6
# SF     11
# DC     16
# Chi    21
# Name: B, dtype: int32

# %%
#Select by multiple columns
dframe[['B','E']]
# Out:
#       B   E
# NYC   1   4
# LA    6   9
# SF   11  14
# DC   16  19
# Chi  21  24

# %%
#Can also use boolean
dframe[dframe['C']>8]
# Out:
#       A   B   C   D   E
# SF   10  11  12  13  14
# DC   15  16  17  18  19
# Chi  20  21  22  23  24

# %%
#Can also just shoe a boolean DataFrame
dframe> 10
# Out:
#          A      B      C      D      E
# NYC  False  False  False  False  False
# LA   False  False  False  False  False
# SF   False   True   True   True   True
# DC    True   True   True   True   True
# Chi   True   True   True   True   True

# %%
#Can alos use ix as previously discussed to label-index
dframe.loc['LA']
# Out:
# A    5
# B    6
# C    7
# D    8
# E    9
# Name: LA, dtype: int32

# %%
#Another example
dframe.iloc[2:,1]
# Out:
# SF     11
# DC     16
# Chi    21
# Name: B, dtype: int32

# %% [markdown]
# #### Rank and Sort

# %%
#Sorting by index
ser1 = Series(range(3),index=['C','A','B'])

#show
ser1
# Out:
# C    0
# A    1
# B    2
# dtype: int64

# %%
#Now sort_index
ser1.sort_index()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
#Can sort a Series by its values
ser1.sort_values()
# Out:
# C    0
# A    1
# B    2
# dtype: int64

# %%
#Lets see how ranking works

from numpy.random import randn
ser2 = Series(randn(10))

#Show
ser2
# Out:
# 0   -1.766494
# 1    1.326755
# 2   -1.045370
# 3   -0.310090
# 4   -0.261858
# 5    0.109472
# 6   -1.310249
# 7    0.531708
# 8   -1.507206
# 9    0.093741
# dtype: float64

# %%
#This will show you the rank used if you sort the series
ser2.rank()
# Out:
# 0     1.0
# 1    10.0
# 2     4.0
# 3     5.0
# 4     6.0
# 5     8.0
# 6     3.0
# 7     9.0
# 8     2.0
# 9     7.0
# dtype: float64

# %%
#Lets sort it now
ser2.sort_values(inplace=True)
#Show
ser2
# Out:
# 0   -1.766494
# 8   -1.507206
# 6   -1.310249
# 2   -1.045370
# 3   -0.310090
# 4   -0.261858
# 9    0.093741
# 5    0.109472
# 7    0.531708
# 1    1.326755
# dtype: float64

# %%
#After sorting let's check the rank and see iof it makes sense
ser2.rank()
# Out:
# 0     1.0
# 8     2.0
# 6     3.0
# 2     4.0
# 3     5.0
# 4     6.0
# 9     7.0
# 5     8.0
# 7     9.0
# 1    10.0
# dtype: float64

# %%
ser2
# Out:
# 0   -1.766494
# 8   -1.507206
# 6   -1.310249
# 2   -1.045370
# 3   -0.310090
# 4   -0.261858
# 9    0.093741
# 5    0.109472
# 7    0.531708
# 1    1.326755
# dtype: float64
